# %% [markdown]
# - http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html

# %%
import cv2
from PIL import Image

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = cv2.imread("/Users/DboyLiao/Documents/Python_Learning/CV_w_Python/ipynbs/559965600226_origin.jpg")
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
eye_detector = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
gray()
imshow(gray_img)

# %%
faces = face_detector.detectMultiScale(gray_img)

# %%
faces
# Out:
# ()

# %%
print face_detector.detectMultiScale.__doc__
# Out:
# detectMultiScale(image[, scaleFactor[, minNeighbors[, flags[, minSize[, maxSize]]]]]) -> objects  or  detectMultiScale(image, rejectLevels, levelWeights[, scaleFactor[, minNeighbors[, flags[, minSize[, maxSize[, outputRejectLevels]]]]]]) -> objects

# %%
faces
# Out:
# ()

# %%
eyes = eye_detector.detectMultiScale(gray_img)

# %%
eyes
# Out:
# ()

# %%
faces = face_detector.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_detector.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
